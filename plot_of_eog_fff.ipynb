# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibtisam-a/Project-Implementation/blob/master/plot_of_eog_fff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd 

plt.figure(figsize=(9,3.8))
n = [379 , 759, 1519, 3039, 6079]
ni = list(range(len(n)))
n2 = [379 , 759, 1519]
n2i = list(range(len(n2)))
n3 = [379 , 759, 1519, 3039]
n3i = list(range(len(n3)))
eog = [2.61430,3.11837,3.12768]  
eog1 = [1.8864,1.8942,2.1693, 2.5954, 2.7422]
eog2 = [2.3831, 2.4783, 3.6863, 3.6416,  2.08166]
eog3 = [1.7152, 2.3077, 3.4349, 3.2769,  2.7746]
eog5 = [2.1231,  2.8430, 2.8723, 2.9366, 3.0736]
#Iterative methods
eog6 = [2.7072, 2.8084, 2.8733 ]
eog7 = [1.75742, 2.55544, 2.83294, 2.89904, 2.97268]
plt.ylim(1.6,3.8)
plt.plot(n2i,eog, c='gold', label='Kronecker product') #kron
plt.plot(ni,eog1, c='RoyalBlue', label='Bartels-Stewart Algo')
plt.plot(ni,eog2, c='tan', label='Bartels-sylvester')
plt.plot(ni,eog3, c='salmon',label='Sim-tra-linalg.eig')
plt.plot(ni,eog5, c='c',label='Shifted-Sys-spsolve')
#Iterative methods
plt.plot(n2i,eog6, c='m',label='Grad_Based-Iter')
plt.plot(ni,eog7, c='HotPink',label='Prec_MCG-Iter')
plt.xlabel('Problem Size (n)')
plt.ylabel('EOG')
plt.xticks(ni, n)
plt.tight_layout()
plt.grid(axis='y')
plt.legend(bbox_to_anchor=(1.27, 1),loc='upper right')

# %%
GBM

eog6 = [2.7072, 2.8084, 2.8733 ]

eog7 = [1.75742, 2.55544, 2.83294, 2.89904, 2.97268]

# %%
import numpy as np
h0=0.00033
h1=0.00016
e0=4.24396e-06
e1=  1.06088e-06               # 0.0010  0.0002   6.8030e-05   1.69860e-05     4.24396e-06   1.06088e-06
#e-05
eoc=(np.log(e1/e0))/(np.log(h1/h0))
eoc

import numpy as np
n0=6079
n1=12159
t0= 186.26687 #  0.02221 ,  0.07544,  0.44497, 3.17645,  23.71677, 186.26687
t1=  
eog=(np.log(t1/t0))/(np.log(n1/n0))
eog

# %%
# h size

0.00529
0.00261         
0.0013
0.00066  
0.00033
0.00016 
0.00008
