# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibtisam-a/Project-Implementation/blob/master/plot_of_eog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd 

plt.figure(figsize=(9,3.8))
n = [379 , 759, 1519, 3039, 6079]
ni = list(range(len(n)))
n2 = [379 , 759, 1519]
n2i = list(range(len(n2)))
n3 = [379 , 759, 1519, 3039]
n3i = list(range(len(n3)))
eog = [2.61430,3.11837,3.12768]  
eog1 = [1.88640,1.89421,2.16938, 2.59543, 2.74224]
eog2 = [2.38315, 2.47833, 3.68630, 3.64163,  2.08166]
eog3 = [1.71525, 2.30772, 3.43491, 3.27690,  2.77466]
eog5 = [2.12313,  2.84307, 2.87235, 2.93660, 3.07361]
#Iterative methods
eog6 = [2.70720, 2.80849, 2.87335 ]
eog7 = [1.75742, 2.55544, 2.83294, 2.89904, 2.97268]
plt.ylim(1.6,3.8)
plt.plot(n2i,eog, c='gold', label='Kronecker product') #kron
plt.plot(ni,eog1, c='RoyalBlue', label='Bartels-Stewart Algo')
plt.plot(ni,eog2, c='tan', label='Bartels-sylvester')
plt.plot(ni,eog3, c='salmon',label='Sim-tra-linalg.eig')
plt.plot(ni,eog5, c='c',label='Shifted-Sys-spsolve')
#Iterative methods
plt.plot(n2i,eog6, c='m',label='Grad_Based-Iter')
plt.plot(ni,eog7, c='HotPink',label='Prec_MCG-Iter')
plt.xlabel('Problem Size (n)')
plt.ylabel('EOG')
plt.xticks(ni, n)
plt.tight_layout()
plt.grid(axis='y')
plt.legend(bbox_to_anchor=(1.27, 1),loc='upper right')

# %%
#To calculate the EOC and EOG
import numpy as np
h0=0.00033
h1=0.00016
e0=4.24396e-06
e1=  1.06088e-06               
#e-05
eoc=(np.log(e1/e0))/(np.log(h1/h0))
eoc

import numpy as np
n0=6079
n1=12159
t0= 186.26687 
t1=  
eog=(np.log(t1/t0))/(np.log(n1/n0))
eog
